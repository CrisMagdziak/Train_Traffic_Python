# %% [markdown]
# ### Import for liblaries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import DataCleainingFunctions as dc

# %% [markdown]
# ### Importing CSV files

# %%
df = pd.read_csv('CSV\Regularities_by_liaisons_Trains_France.csv')

# %% [markdown]
# #### Check Data for DataFrame -> df

# %%
dc.stats(df)
# Out:
# ### Shape ###
# Rows: 7806
# Columns: 32
#
#
# ### Data Types ###
# Year                                                                                                                     int64
# Month                                                                                                                  float64
# Departure station                                                                                                       object
# Arrival station                                                                                                         object
# Average travel time (min)                                                                                              float64
# Number of expected circulations                                                                                        float64
# Number of cancelled trains                                                                                             float64
# ...

# %%
df.describe()
# Out:
#               Year        Month  Average travel time (min)  \
# count  7806.000000  7806.000000                7743.000000
# mean   2017.345119     6.216372                 166.759261
# std       1.596611     3.440601                  80.737092
# min    2015.000000     1.000000                  35.888889
# 25%    2016.000000     3.000000                 100.643605
# 50%    2017.000000     6.000000                 162.178808
# 75%    2019.000000     9.000000                 207.885957
# max    2020.000000    12.000000                 786.500000
#
#        Number of expected circulations  Number of cancelled trains  \
# count                      7743.000000                 7806.000000
# mean                        266.510913                    7.911478
# std                         157.456548                   20.997806
# min                           1.000000                    0.000000
# 25%                         163.000000                    0.000000
# ...

# %%
df.head()
# Out:
#    Year  Month   Departure station      Arrival station  \
# 0  2019    7.0           ANGOULEME   PARIS MONTPARNASSE
# 1  2019    7.0  PARIS MONTPARNASSE    LA ROCHELLE VILLE
# 2  2019    7.0             LE MANS   PARIS MONTPARNASSE
# 3  2019    7.0             ST MALO   PARIS MONTPARNASSE
# 4  2019    7.0  PARIS MONTPARNASSE  ST PIERRE DES CORPS
#
#    Average travel time (min)  Number of expected circulations  \
# 0                 131.914980                            247.0
# 1                 175.611570                            242.0
# 2                  62.395349                            435.0
# 3                 172.421053                            114.0
# 4                  67.310000                            404.0
#
#    Number of cancelled trains  Number of late trains at departure  \
# 0                         0.0                               191.0
# 1                         0.0                               178.0
# ...

# %%
df.sample(15)
# Out:
#       Year  Month           Departure station             Arrival station  \
# 2354  2015   10.0                  PARIS NORD                       LILLE
# 6443  2019    7.0                  PARIS LYON                       NIMES
# 1635  2018    4.0             PARIS VAUGIRARD                      RENNES
# 7603  2020    6.0          PARIS MONTPARNASSE           ANGERS SAINT LAUD
# 4169  2015   12.0                  PARIS LYON  SAINT ETIENNE CHATEAUCREUX
# 1231  2015    6.0                  PARIS LYON                    GRENOBLE
# 1229  2015    7.0                  PARIS LYON                      ITALIE
# 7631  2020    5.0                  PARIS NORD                   DUNKERQUE
# 2557  2018   11.0                  PARIS LYON                      ZURICH
# 3458  2018    2.0  BESANCON FRANCHE COMTE TGV                  PARIS LYON
# 816   2018    7.0          PARIS MONTPARNASSE                     ST MALO
# 595   2018    5.0                      ANNECY                  PARIS LYON
# ...

# %%
def solution(string):
    pass
